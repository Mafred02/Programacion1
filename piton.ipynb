# %% [markdown]
# <a href="https://colab.research.google.com/github/Mafred02/Programacion1/blob/main/piton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#10-17 de marzo 1er Parcial
